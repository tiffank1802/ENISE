# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_fwf("datas/S11_Ss.rpt"
                #  , skiprows=19, nrows=3233, 
                #  colspecs=[(17, 33), (33, 39), (39, 59), (59, 70)],
                #  encoding='latin1'
                )
S11_S = df.values;S11_S
# Out:
# array([['Field Output Report, written Fri Feb  6 10:27:14 2026'],
#        ['Source 1'],
#        ['---------'],
#        ...,
#        ['At Element                            3075            3233'],
#        ['Int Pt                               1               1'],
#        ['Total                         3.04126              0.']],
#       dtype=object)
